# %% [markdown]
# # Backdoor Unlearning
#
# ## Outline
#
# 1. Experimental setup (generating configs)
# 2. Clean model training
# 3. Poisoned model training
# 4. First-order unlearning
# 5. Second-order unlearning
# 6. Visualizing results

# %% [markdown]
# ## Experimental Setup
#
# - All configurations to test are defined in the `[train|poison|unlearn].json` files (see below).
# - If parameters are passed as list, all their combinations are tested in a grid-search manner.
# - Only a single combination is provided for this demo. The original combinations are in `Applications/Poisoning/configs`
# - The function generates directories and configuration files for each combination. They are later used by an evaluation script to run the experiment. This allows for parallelization and distributed execution.

# %%
import sys
sys.path.append('../')

# %%
# only if you are using CUDA devices
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
from conf import BASE_DIR
from Applications.Poisoning.gen_configs import main as gen_configs

model_folder = BASE_DIR/'models'/'poisoning'
train_conf = BASE_DIR/'Applications'/'Poisoning'/'configs'/'demo'/'train.json'
poison_conf = BASE_DIR/'Applications'/'Poisoning'/'configs'/'demo'/'poison.json'
unlearn_conf = BASE_DIR/'Applications'/'Poisoning'/'configs'/'demo'/'unlearn.json'

gen_configs(model_folder, train_conf, poison_conf, unlearn_conf)

# %% [markdown]
# ## Clean Model Training
#
# - Train a clean model for reference.

# %%
from Applications.Poisoning.train import main as train

# train one clean and one poisoned model
train(model_folder=model_folder/'clean', dataset='cifar100')
# Out:
# 2024-06-15 22:27:40.273603: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/team1337/.local/easybuild_new/software/OpenMPI/4.0.5-GCC-10.2.0/lib:/home/team1337/.local/easybuild_new/software/PMIx/3.1.5-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libfabric/1.11.0-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/UCX/1.9.0-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libevent/2.1.12-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/hwloc/2.2.0-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libpciaccess/0.16-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libxml2/2.9.10-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/XZ/5.2.5-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/numactl/2.0.13-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/binutils/2.35-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/zlib/1.2.11-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/GCCcore/10.2.0/lib64
# 2024-06-15 22:27:40.273634: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Train Poisoned Model
#
# - Select one of the generated configurations and train a poisoned model.
# - The poisoning uses an `injector` object which can be persisted for reproducibility. It will inject the backdoors/label noise into the same samples according to a seed. In our experiments, we worked with label noise poisoning.

# %%
from Applications.Poisoning.poison.poison_models import train_poisoned
from Applications.Poisoning.configs.demo.config import Config

poisoned_folder = model_folder/'budget-10000'/'seed-42'
poison_kwargs = Config.from_json(poisoned_folder/'poison_config.json')
train_kwargs = Config.from_json(poisoned_folder/'train_config.json')
train_poisoned(model_folder=poisoned_folder, poison_kwargs=poison_kwargs, train_kwargs=train_kwargs, dataset="cifar100")

# %%
poisoned_weights = poisoned_folder/'best_model.hdf5'       # model that has been trained on poisoned data
fo_repaired_weights = poisoned_folder/'fo_repaired.hdf5'   # model weights after unlearning (first-order)
so_repaired_weights = poisoned_folder/'so_repaired.hdf5'   # model weights after unlearning (second-order)
injector_path = poisoned_folder/'injector.pkl'             # cached injector for reproducibility
clean_results = model_folder/'clean'/'train_results.json'  # path to reference results on clean dataset

# %% [markdown]
# ## Unlearning
#
# - Perform the first-order and second-order unlearning. The unlearning is wrapped in a function that
#     - loads the clean data, saves the original labels
#     - injects the poison (label noise)
#     - creates difference set Z using `injector.injected_idx`
#     - main unlearning happens in `Applications.Poisoning.unlearn.common.py:unlearn_update` and the thereby called `iter_approx_retraining` method
# - The variable naming follows the following ideas:
#     - `z_x`, `z_y`: features (x) and labels (y) in set `Z`
#     - `z_x_delta`, `z_y_delta`: changed features and labels (`z_x == z_x_delta` here and `z_y_delta` contains the original (fixed) labels)
# - A word about why iterative:
#     - The approximate retraining is configured to unlearn the desired changes in one step.
#     - To avoid putting a lot of redundant erroneous samples in the changing set `Z`, the iterative version
#         - takes a sub-sample (`prio_idx`) of `hvp_batch_size` in the delta set `Z`
#         - makes one unlearning step
#         - recalculates the delta set and focuses only on remaining errors
#     - The idea here is that similar to learning, it is better to work iteratively in batches since the approximation quality of the inverse hessian matrix decreases with the number of samples included (and the step size)

# %%
from Applications.Poisoning.unlearn.first_order import run_experiment as fo_experiment
from Applications.Poisoning.unlearn.second_order import run_experiment as so_experiment

fo_unlearn_kwargs = Config.from_json(poisoned_folder/'first-order'/'unlearn_config.json')
so_unlearn_kwargs = Config.from_json(poisoned_folder/'second-order'/'unlearn_config.json')

fo_experiment(poisoned_folder/'first-order', train_kwargs, poison_kwargs, fo_unlearn_kwargs, dataset='cifar100')

# %%
so_experiment(poisoned_folder/'second-order', train_kwargs, poison_kwargs, so_unlearn_kwargs, dataset='cifar100')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  batch_normalization (BatchN  (None, 32, 32, 128)      512
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_1 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 128)      0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_2 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 1,847,012
# Trainable params: 1,844,452
# Non-trainable params: 2,560
# _________________________________________________________________
# None
# Early stopping at iteration 190. Update norm 2717570.6533966064 > [2706078.989212036, 20]
# Early stopping at iteration 90. Update norm 2042002.5946044922 > [2034458.294555664, 20]
# Early stopping at iteration 105. Update norm 2281209.775390625 > [2261616.6411132812, 20]
# Early stopping at iteration 96. Update norm 3906425.778076172 > [3574665.7709960938, 20]
# Early stopping at iteration 168. Update norm 2777818.2486572266 > [2754105.822631836, 20]
# Early stopping at iteration 56. Update norm 4107575.2966308594 > [4071216.5599365234, 20]
# Early stopping at iteration 68. Update norm 839402.4780883789 > [828687.0669555664, 20]
# WARNING:tensorflow:5 out of the last 18 calls to <function get_gradients_diff at 0x7fff00c60560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Early stopping at iteration 62. Update norm 310059.52112579346 > [308237.2528915405, 20]
# WARNING:tensorflow:6 out of the last 19 calls to <function get_gradients_diff at 0x7fff00c60560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Early stopping at iteration 56. Update norm 208724.99160766602 > [208536.3888168335, 20]
# Early stopping at iteration 68. Update norm 192531.1781654358 > [191033.78505325317, 20]
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)       3584
#
#  batch_normalization_7 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_8 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_9 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_10 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_11 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_12 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_5 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
#  batch_normalization_13 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_3 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 1,847,012
# Trainable params: 1,844,452
# Non-trainable params: 2,560
# _________________________________________________________________
# None

# %% [markdown]
# ## Visualizing the Results
#
# - To give some notion of how well the unlearning worked, we plot confusion matrices before and after unlearning.
# - This is just an example and not required for unlearning.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams

# figure size in inches optional
rcParams['figure.figsize'] = 11 ,8

# %%
cm_before = mpimg.imread(poisoned_folder/'first-order'/'cm'/'cm_unlearning_00.png')
cm_after = mpimg.imread(poisoned_folder/'first-order'/'cm'/'cm_unlearning_01.png')

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(cm_before)
ax[1].imshow(cm_after)
ax[0].grid(False)
ax[1].grid(False)
ax[0].tick_params(left=False, right=False , labelleft=False, labelbottom=False, bottom=False)
ax[1].tick_params(left=False, right=False , labelleft=False, labelbottom=False, bottom=False)

plt.show()

# %%
cm_before = mpimg.imread(poisoned_folder/'second-order'/'cm'/'cm_unlearning_00.png')
cm_after = mpimg.imread(poisoned_folder/'second-order'/'cm'/'cm_unlearning_01.png')

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(cm_before)
ax[1].imshow(cm_after)
ax[0].grid(False)
ax[1].grid(False)
ax[0].tick_params(left=False, right=False , labelleft=False, labelbottom=False, bottom=False)
ax[1].tick_params(left=False, right=False , labelleft=False, labelbottom=False, bottom=False)

plt.show()

# %% [markdown]
# As you can see, the second-order unlearning is able to fix some of the missing accuracy. However, it can also be observed that the unlearning is not exact in the non-convex setting.

# %% [markdown]
# # ResNet50

# %%
import sys
sys.path.append('../')
 
from conf import BASE_DIR
from Applications.Poisoning.gen_configs import main as gen_configs

model_folder = BASE_DIR/'models'/'poisoning'
train_conf = BASE_DIR/'Applications'/'Poisoning'/'configs'/'demo'/'train.json'
poison_conf = BASE_DIR/'Applications'/'Poisoning'/'configs'/'demo'/'poison.json'
unlearn_conf = BASE_DIR/'Applications'/'Poisoning'/'configs'/'demo'/'unlearn.json'

gen_configs(model_folder, train_conf, poison_conf, unlearn_conf)

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
from Applications.Poisoning.train import main as train

# train one clean and one poisoned model
train(model_folder=model_folder/'clean', dataset='cifar100', modelname='ResNet50')
# Out:
# 2024-06-21 13:48:25.647536: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/team1337/.local/easybuild_new/software/OpenMPI/4.0.5-GCC-10.2.0/lib:/home/team1337/.local/easybuild_new/software/PMIx/3.1.5-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libfabric/1.11.0-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/UCX/1.9.0-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libevent/2.1.12-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/hwloc/2.2.0-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libpciaccess/0.16-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libxml2/2.9.10-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/XZ/5.2.5-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/numactl/2.0.13-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/binutils/2.35-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/zlib/1.2.11-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/GCCcore/10.2.0/lib64
# 2024-06-21 13:48:25.647569: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-06-21 13:48:44.909957: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/team1337/.local/easybuild_new/software/OpenMPI/4.0.5-GCC-10.2.0/lib:/home/team1337/.local/easybuild_new/software/PMIx/3.1.5-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libfabric/1.11.0-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/UCX/1.9.0-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libevent/2.1.12-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/hwloc/2.2.0-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libpciaccess/0.16-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/libxml2/2.9.10-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/XZ/5.2.5-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/numactl/2.0.13-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/binutils/2.35-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/zlib/1.2.11-GCCcore-10.2.0/lib:/home/team1337/.local/easybuild_new/software/GCCcore/10.2.0/lib64
# 2024-06-21 13:48:44.910010: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-06-21 13:48:44.910058: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (node03): /proc/driver/nvidia/version does not exist
# 2024-06-21 13:48:44.910328: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/ameck.dosseh/conite/MU_ENV/lib/python3.7/site-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# Epoch 1/100
# 782/782 [==============================] - 181s 220ms/step - loss: 4.5647 - accuracy: 0.0161 - val_loss: 4.9892 - val_accuracy: 0.0250
# Epoch 2/100
# 782/782 [==============================] - 171s 219ms/step - loss: 4.2460 - accuracy: 0.0372 - val_loss: 4.3021 - val_accuracy: 0.0446
# Epoch 3/100
# 782/782 [==============================] - ETA: 0s - loss: 4.0585 - accuracy: 0.0561Decreasing learning rate to 0.0050000
# 782/782 [==============================] - 172s 220ms/step - loss: 4.0585 - accuracy: 0.0561 - val_loss: 4.8516 - val_accuracy: 0.0648
# Epoch 4/100
# 782/782 [==============================] - 172s 220ms/step - loss: 4.0288 - accuracy: 0.0589 - val_loss: 3.9550 - val_accuracy: 0.0704
# Epoch 5/100
# 782/782 [==============================] - 172s 220ms/step - loss: 3.8996 - accuracy: 0.0781 - val_loss: 3.9259 - val_accuracy: 0.0836
# Epoch 6/100
# 782/782 [==============================] - ETA: 0s - loss: 3.7854 - accuracy: 0.0917Decreasing learning rate to 0.0025000
# 782/782 [==============================] - 172s 220ms/step - loss: 3.7854 - accuracy: 0.0917 - val_loss: 4.0985 - val_accuracy: 0.1046
# Epoch 7/100
# 782/782 [==============================] - 172s 220ms/step - loss: 3.7615 - accuracy: 0.0985 - val_loss: 3.5844 - val_accuracy: 0.1326
# Epoch 8/100
# 782/782 [==============================] - 174s 222ms/step - loss: 3.6781 - accuracy: 0.1085 - val_loss: 3.5672 - val_accuracy: 0.1350
# Epoch 9/100
# 782/782 [==============================] - ETA: 0s - loss: 3.6237 - accuracy: 0.1196Decreasing learning rate to 0.0012500
# 782/782 [==============================] - 172s 220ms/step - loss: 3.6237 - accuracy: 0.1196 - val_loss: 3.5866 - val_accuracy: 0.1408
# Epoch 10/100
# 782/782 [==============================] - 172s 219ms/step - loss: 3.5957 - accuracy: 0.1225 - val_loss: 3.4200 - val_accuracy: 0.1578
# Epoch 11/100
# 782/782 [==============================] - ETA: 0s - loss: 3.5460 - accuracy: 0.1324Decreasing learning rate to 0.0006250
# 782/782 [==============================] - 174s 222ms/step - loss: 3.5460 - accuracy: 0.1324 - val_loss: 3.4281 - val_accuracy: 0.1694
# Epoch 12/100
# 782/782 [==============================] - 172s 220ms/step - loss: 3.5374 - accuracy: 0.1323 - val_loss: 3.3897 - val_accuracy: 0.1662
# Epoch 13/100
# 782/782 [==============================] - 174s 222ms/step - loss: 3.5016 - accuracy: 0.1394 - val_loss: 3.3520 - val_accuracy: 0.1778
# Epoch 14/100
# 782/782 [==============================] - 173s 221ms/step - loss: 3.4869 - accuracy: 0.1421 - val_loss: 3.3367 - val_accuracy: 0.1824
# Epoch 15/100
# 782/782 [==============================] - 173s 221ms/step - loss: 3.4626 - accuracy: 0.1470 - val_loss: 3.3029 - val_accuracy: 0.1882
# Epoch 16/100
# 782/782 [==============================] - 173s 221ms/step - loss: 3.4381 - accuracy: 0.1479 - val_loss: 3.2743 - val_accuracy: 0.1930
# Epoch 17/100
# 782/782 [==============================] - ETA: 0s - loss: 3.4154 - accuracy: 0.1545Decreasing learning rate to 0.0003125
# 782/782 [==============================] - 172s 220ms/step - loss: 3.4154 - accuracy: 0.1545 - val_loss: 3.2912 - val_accuracy: 0.1942
# Epoch 18/100
# 782/782 [==============================] - 173s 221ms/step - loss: 3.4033 - accuracy: 0.1553 - val_loss: 3.2713 - val_accuracy: 0.1936
# Epoch 19/100
# 782/782 [==============================] - 172s 221ms/step - loss: 3.3947 - accuracy: 0.1598 - val_loss: 3.2543 - val_accuracy: 0.1984
# Epoch 20/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3822 - accuracy: 0.1612Decreasing learning rate to 0.0001562
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3822 - accuracy: 0.1612 - val_loss: 3.2573 - val_accuracy: 0.2016
# Epoch 21/100
# 782/782 [==============================] - 173s 221ms/step - loss: 3.3794 - accuracy: 0.1595 - val_loss: 3.2513 - val_accuracy: 0.1954
# Epoch 22/100
# 782/782 [==============================] - 172s 219ms/step - loss: 3.3668 - accuracy: 0.1619 - val_loss: 3.2498 - val_accuracy: 0.1994
# Epoch 23/100
# 782/782 [==============================] - 173s 221ms/step - loss: 3.3568 - accuracy: 0.1656 - val_loss: 3.2428 - val_accuracy: 0.1972
# Epoch 24/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3533 - accuracy: 0.1656Decreasing learning rate to 0.0000781
# 782/782 [==============================] - 173s 221ms/step - loss: 3.3533 - accuracy: 0.1656 - val_loss: 3.2486 - val_accuracy: 0.1968
# Epoch 25/100
# 782/782 [==============================] - 173s 221ms/step - loss: 3.3436 - accuracy: 0.1670 - val_loss: 3.2398 - val_accuracy: 0.1966
# Epoch 26/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3405 - accuracy: 0.1674Decreasing learning rate to 0.0000391
# 782/782 [==============================] - 173s 221ms/step - loss: 3.3405 - accuracy: 0.1674 - val_loss: 3.2403 - val_accuracy: 0.1972
# Epoch 27/100
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3433 - accuracy: 0.1698 - val_loss: 3.2332 - val_accuracy: 0.1982
# Epoch 28/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3414 - accuracy: 0.1699Decreasing learning rate to 0.0000195
# 782/782 [==============================] - 172s 219ms/step - loss: 3.3414 - accuracy: 0.1699 - val_loss: 3.2350 - val_accuracy: 0.2008
# Epoch 29/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3462 - accuracy: 0.1644Decreasing learning rate to 0.0000098
# 782/782 [==============================] - 173s 221ms/step - loss: 3.3462 - accuracy: 0.1644 - val_loss: 3.2373 - val_accuracy: 0.2010
# Epoch 30/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3421 - accuracy: 0.1673Decreasing learning rate to 0.0000049
# 782/782 [==============================] - 172s 219ms/step - loss: 3.3421 - accuracy: 0.1673 - val_loss: 3.2372 - val_accuracy: 0.1974
# Epoch 31/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3406 - accuracy: 0.1690Decreasing learning rate to 0.0000024
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3406 - accuracy: 0.1690 - val_loss: 3.2335 - val_accuracy: 0.1998
# Epoch 32/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3356 - accuracy: 0.1702Decreasing learning rate to 0.0000012
# 782/782 [==============================] - 173s 221ms/step - loss: 3.3356 - accuracy: 0.1702 - val_loss: 3.2379 - val_accuracy: 0.2014
# Epoch 33/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3377 - accuracy: 0.1695Decreasing learning rate to 0.0000006
# 782/782 [==============================] - 172s 219ms/step - loss: 3.3377 - accuracy: 0.1695 - val_loss: 3.2358 - val_accuracy: 0.1986
# Epoch 34/100
# 782/782 [==============================] - 171s 219ms/step - loss: 3.3384 - accuracy: 0.1680 - val_loss: 3.2326 - val_accuracy: 0.2014
# Epoch 35/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3451 - accuracy: 0.1684Decreasing learning rate to 0.0000003
# 782/782 [==============================] - 171s 219ms/step - loss: 3.3451 - accuracy: 0.1684 - val_loss: 3.2415 - val_accuracy: 0.1984
# Epoch 36/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3397 - accuracy: 0.1677Decreasing learning rate to 0.0000002
# 782/782 [==============================] - 171s 219ms/step - loss: 3.3397 - accuracy: 0.1677 - val_loss: 3.2369 - val_accuracy: 0.2004
# Epoch 37/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3395 - accuracy: 0.1695Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3395 - accuracy: 0.1695 - val_loss: 3.2410 - val_accuracy: 0.1992
# Epoch 38/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3473 - accuracy: 0.1666Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 172s 219ms/step - loss: 3.3473 - accuracy: 0.1666 - val_loss: 3.2411 - val_accuracy: 0.2004
# Epoch 39/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3448 - accuracy: 0.1665Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 172s 219ms/step - loss: 3.3448 - accuracy: 0.1665 - val_loss: 3.2440 - val_accuracy: 0.1988
# Epoch 40/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3444 - accuracy: 0.1670Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3444 - accuracy: 0.1670 - val_loss: 3.2414 - val_accuracy: 0.1994
# Epoch 41/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3373 - accuracy: 0.1666Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3373 - accuracy: 0.1666 - val_loss: 3.2379 - val_accuracy: 0.1994
# Epoch 42/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3348 - accuracy: 0.1700Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 173s 221ms/step - loss: 3.3348 - accuracy: 0.1700 - val_loss: 3.2389 - val_accuracy: 0.1976
# Epoch 43/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3489 - accuracy: 0.1696Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 171s 218ms/step - loss: 3.3489 - accuracy: 0.1696 - val_loss: 3.2407 - val_accuracy: 0.1976
# Epoch 44/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3369 - accuracy: 0.1708Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3369 - accuracy: 0.1708 - val_loss: 3.2354 - val_accuracy: 0.1980
# Epoch 45/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3507 - accuracy: 0.1658Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3507 - accuracy: 0.1658 - val_loss: 3.2446 - val_accuracy: 0.1972
# Epoch 46/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3338 - accuracy: 0.1690Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 173s 222ms/step - loss: 3.3338 - accuracy: 0.1690 - val_loss: 3.2378 - val_accuracy: 0.1984
# Epoch 47/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3486 - accuracy: 0.1657Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3486 - accuracy: 0.1657 - val_loss: 3.2405 - val_accuracy: 0.2000
# Epoch 48/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3369 - accuracy: 0.1685Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3369 - accuracy: 0.1685 - val_loss: 3.2382 - val_accuracy: 0.1998
# Epoch 49/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3411 - accuracy: 0.1702Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 171s 219ms/step - loss: 3.3411 - accuracy: 0.1702 - val_loss: 3.2410 - val_accuracy: 0.1982
# Epoch 50/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3380 - accuracy: 0.1665Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 171s 219ms/step - loss: 3.3380 - accuracy: 0.1665 - val_loss: 3.2378 - val_accuracy: 0.1998
# Epoch 51/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3443 - accuracy: 0.1665Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 171s 219ms/step - loss: 3.3443 - accuracy: 0.1665 - val_loss: 3.2386 - val_accuracy: 0.1984
# Epoch 52/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3368 - accuracy: 0.1698Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 171s 218ms/step - loss: 3.3368 - accuracy: 0.1698 - val_loss: 3.2421 - val_accuracy: 0.1996
# Epoch 53/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3412 - accuracy: 0.1670Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3412 - accuracy: 0.1670 - val_loss: 3.2463 - val_accuracy: 0.1980
# Epoch 54/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3416 - accuracy: 0.1677Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 171s 219ms/step - loss: 3.3416 - accuracy: 0.1677 - val_loss: 3.2330 - val_accuracy: 0.1988
# Epoch 55/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3352 - accuracy: 0.1662Decreasing learning rate to 0.0000001
# 782/782 [==============================] - 172s 220ms/step - loss: 3.3352 - accuracy: 0.1662 - val_loss: 3.2364 - val_accuracy: 0.1978
# Epoch 56/100
# 782/782 [==============================] - ETA: 0s - loss: 3.3431 - accuracy: 0.1665Decreasing learning rate to 0.0000001
# Restoring model weights from the end of the best epoch: 46.
# 782/782 [==============================] - 171s 218ms/step - loss: 3.3431 - accuracy: 0.1665 - val_loss: 3.2398 - val_accuracy: 0.1994
# Epoch 00056: early stopping
# Best model has test loss 3.333848714828491 after 46 epochs
# /home/ameck.dosseh/conite/MU_ENV/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ameck.dosseh/conite/MU_ENV/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ameck.dosseh/conite/MU_ENV/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
